# %%
#Version 3.9
import numpy as np
import pandas as pd

# %%
#create a PANDA series s
s = pd.Series([1,3,5,np.nan,6,8])

#view content of series
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#create NUMPY Dataframe = numpy-array with index=daytime and colums with labels
dates = pd.date_range("20210301", periods=6)

#view content of Dataframe(df)
dates
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
#create dataframe = df
#randn(r,c) 
    # r=# of rows/dates in this case
    # c=# of columns defined in list at the end 
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064

# %%
#does not display type of index=dates
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
#df2 is a PANDA created by passing a dictionary that can be converted to a series-like
# all columns should have the same lengh, 6 in this case

df2 = pd.DataFrame(
    {
        "F": 1.0,
        #"B": pd.Timestamp("20130102"),
        "B": dates,
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([-3.3] * 6,dtype="float"),
        "E": pd.Categorical(["test", "train", "test", "train", "five", "six"]),
        "A": "foo",
    }
)

df2
# Out:
#      F          B    C    D      E    A
# 0  1.0 2021-03-01  1.0 -3.3   test  foo
# 1  1.0 2021-03-02  1.0 -3.3  train  foo
# 2  1.0 2021-03-03  1.0 -3.3   test  foo
# 3  1.0 2021-03-04  1.0 -3.3  train  foo
# 4  1.0 2021-03-05  1.0 -3.3   five  foo
# 5  1.0 2021-03-06  1.0 -3.3    six  foo

# %%
df2.dtypes
# Out:
# F           float64
# B    datetime64[ns]
# C           float32
# D           float64
# E          category
# A            object
# dtype: object

# %%
#
df.head()
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565

# %%
df2.head()
# Out:
#      F          B    C    D      E    A
# 0  1.0 2021-03-01  1.0 -3.3   test  foo
# 1  1.0 2021-03-02  1.0 -3.3  train  foo
# 2  1.0 2021-03-03  1.0 -3.3   test  foo
# 3  1.0 2021-03-04  1.0 -3.3  train  foo
# 4  1.0 2021-03-05  1.0 -3.3   five  foo

# %%
#
df.tail(4)
# Out:
#                    A         B         C         D
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064

# %%
df.index
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# from pandas to numpy
#df is still the same as shown when typing df
df.to_numpy()
# Out:
# array([[-0.13645733, -1.68047872, -0.78533198, -1.75466139],
#        [ 1.22928234,  0.98451766, -0.55358957, -1.03101619],
#        [ 1.49975327,  0.60588489,  0.14162272,  0.31235755],
#        [ 0.66170262, -1.33080689, -0.99123938,  2.11915634],
#        [-0.15193568, -0.55058504, -1.59363572,  0.06156485],
#        [ 0.85169317,  0.40195752, -0.37789832, -0.6180637 ]])

# %%
df
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2021-03-01 00:00:00'), 1.0, -3.3, 'test', 'foo'],
#        [1.0, Timestamp('2021-03-02 00:00:00'), 1.0, -3.3, 'train', 'foo'],
#        [1.0, Timestamp('2021-03-03 00:00:00'), 1.0, -3.3, 'test', 'foo'],
#        [1.0, Timestamp('2021-03-04 00:00:00'), 1.0, -3.3, 'train', 'foo'],
#        [1.0, Timestamp('2021-03-05 00:00:00'), 1.0, -3.3, 'five', 'foo'],
#        [1.0, Timestamp('2021-03-06 00:00:00'), 1.0, -3.3, 'six', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.659006 -0.261585 -0.693345 -0.151777
# std    0.686964  1.094128  0.587186  1.339985
# min   -0.151936 -1.680479 -1.593636 -1.754661
# 25%    0.063083 -1.135751 -0.939763 -0.927778
# 50%    0.756698 -0.074314 -0.669461 -0.278249
# 75%    1.134885  0.554903 -0.421821  0.249659
# max    1.499753  0.984518  0.141623  2.119156

# %%
df['A'].describe()
# Out:
# count    6.000000
# mean     0.659006
# std      0.686964
# min     -0.151936
# 25%      0.063083
# 50%      0.756698
# 75%      1.134885
# max      1.499753
# Name: A, dtype: float64

# %%
df2.describe()
# Out:
#          F    C             D
# count  6.0  6.0  6.000000e+00
# mean   1.0  1.0 -3.300000e+00
# std    0.0  0.0  4.864754e-16
# min    1.0  1.0 -3.300000e+00
# 25%    1.0  1.0 -3.300000e+00
# 50%    1.0  1.0 -3.300000e+00
# 75%    1.0  1.0 -3.300000e+00
# max    1.0  1.0 -3.300000e+00

# %%
df2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
#transpose
df2.T
# Out:
#                      0                    1                    2  \
# F                  1.0                  1.0                  1.0
# B  2021-03-01 00:00:00  2021-03-02 00:00:00  2021-03-03 00:00:00
# C                  1.0                  1.0                  1.0
# D                 -3.3                 -3.3                 -3.3
# E                 test                train                 test
# A                  foo                  foo                  foo
#
#                      3                    4                    5
# F                  1.0                  1.0                  1.0
# B  2021-03-04 00:00:00  2021-03-05 00:00:00  2021-03-06 00:00:00
# C                  1.0                  1.0                  1.0
# D                 -3.3                 -3.3                 -3.3
# E                train                 five                  six
# A                  foo                  foo                  foo

# %%
#sorting by colums = axis1
df2.sort_index(axis=1, ascending=False)
# Out:
#      F      E    D    C          B    A
# 0  1.0   test -3.3  1.0 2021-03-01  foo
# 1  1.0  train -3.3  1.0 2021-03-02  foo
# 2  1.0   test -3.3  1.0 2021-03-03  foo
# 3  1.0  train -3.3  1.0 2021-03-04  foo
# 4  1.0   five -3.3  1.0 2021-03-05  foo
# 5  1.0    six -3.3  1.0 2021-03-06  foo

# %%
#sorting by colums = axis1
df2.sort_index(axis=1, ascending=True)
# Out:
#      A          B    C    D      E    F
# 0  foo 2021-03-01  1.0 -3.3   test  1.0
# 1  foo 2021-03-02  1.0 -3.3  train  1.0
# 2  foo 2021-03-03  1.0 -3.3   test  1.0
# 3  foo 2021-03-04  1.0 -3.3  train  1.0
# 4  foo 2021-03-05  1.0 -3.3   five  1.0
# 5  foo 2021-03-06  1.0 -3.3    six  1.0

# %%
#sorting by values
df2.sort_values(by="E")
# Out:
#      F          B    C    D      E    A
# 4  1.0 2021-03-05  1.0 -3.3   five  foo
# 5  1.0 2021-03-06  1.0 -3.3    six  foo
# 0  1.0 2021-03-01  1.0 -3.3   test  foo
# 2  1.0 2021-03-03  1.0 -3.3   test  foo
# 1  1.0 2021-03-02  1.0 -3.3  train  foo
# 3  1.0 2021-03-04  1.0 -3.3  train  foo

# %%
#df2 is not indexed

df2["E"]
# Out:
# 0     test
# 1    train
# 2     test
# 3    train
# 4     five
# 5      six
# Name: E, dtype: category
# Categories (4, object): ['five', 'six', 'test', 'train']

# %%
#df is indexed

df["B"]

#for multiple columns
#   df.loc[:,["A", "B"]]
# Out:
# 2021-03-01   -1.680479
# 2021-03-02    0.984518
# 2021-03-03    0.605885
# 2021-03-04   -1.330807
# 2021-03-05   -0.550585
# 2021-03-06    0.401958
# Freq: D, Name: B, dtype: float64

# %%
#df can be called in 2 different ways, index or 3:5 method

df[0:3]
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358

# %%
df["20210303":"20210305"]
# Out:
#                    A         B         C         D
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565

# %%
df2[2:4]
# Out:
#      F          B    C    D      E    A
# 2  1.0 2021-03-03  1.0 -3.3   test  foo
# 3  1.0 2021-03-04  1.0 -3.3  train  foo

# %%
df
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064

# %%
#list values of row index=0, i.e. the 1st row
df.loc[dates[0]]
# Out:
# A   -0.136457
# B   -1.680479
# C   -0.785332
# D   -1.754661
# Name: 2021-03-01 00:00:00, dtype: float64

# %%
#display index of dataframe

df.index
# Out:
# DatetimeIndex(['2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04',
#                '2021-03-05', '2021-03-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
# list vars of columns A E C and rows 2-3 (3rd and 4th)
df2.loc[2:3,["A", "E", "C"]]
# Out:
#      A      E    C
# 2  foo   test  1.0
# 3  foo  train  1.0

# %%
df.loc["20210303":"20210305", ["B", "D"]]
# Out:
#                    B         D
# 2021-03-03  0.605885  0.312358
# 2021-03-04 -1.330807  2.119156
# 2021-03-05 -0.550585  0.061565

# %%
df.loc["20210303", ["B", "D"]]
# Out:
# B    0.605885
# D    0.312358
# Name: 2021-03-03 00:00:00, dtype: float64

# %%
df.loc["20210303":"20210303", ["B", "D"]]
# Out:
#                    B         D
# 2021-03-03  0.605885  0.312358

# %%
df.loc["20210303":"20210303", ["B"]]
# Out:
#                    B
# 2021-03-03  0.605885

# %%
df.loc["20210303", ["B"]]
# Out:
# B    0.605885
# Name: 2021-03-03 00:00:00, dtype: float64

# %%
df.at[dates[2],"B"]
# Out:
# 0.6058848928410567

# %%
#equivalent to df[3:4]
df.iloc[3]
# Out:
# A    0.661703
# B   -1.330807
# C   -0.991239
# D    2.119156
# Name: 2021-03-04 00:00:00, dtype: float64

# %%
#equivalent to df.iloc[3]
df[3:4]
# Out:
#                    A         B         C         D
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156

# %%
#rows 4-5 and cols 1-2-3
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2021-03-04  0.661703 -1.330807
# 2021-03-05 -0.151936 -0.550585

# %%
df
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064

# %%
#view with control of order of cols and rows

df.iloc[[3,4],[1,0]]
# Out:
#                    B         A
# 2021-03-04 -1.330807  0.661703
# 2021-03-05 -0.550585 -0.151936

# %%
#list if A>0
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064

# %%
#list only negative values 
df[df<0]
# Out:
#                    A         B         C         D
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661
# 2021-03-02       NaN       NaN -0.553590 -1.031016
# 2021-03-03       NaN       NaN       NaN       NaN
# 2021-03-04       NaN -1.330807 -0.991239       NaN
# 2021-03-05 -0.151936 -0.550585 -1.593636       NaN
# 2021-03-06       NaN       NaN -0.377898 -0.618064

# %%
df2
# Out:
#      F          B    C    D      E    A
# 0  1.0 2021-03-01  1.0 -3.3   test  foo
# 1  1.0 2021-03-02  1.0 -3.3  train  foo
# 2  1.0 2021-03-03  1.0 -3.3   test  foo
# 3  1.0 2021-03-04  1.0 -3.3  train  foo
# 4  1.0 2021-03-05  1.0 -3.3   five  foo
# 5  1.0 2021-03-06  1.0 -3.3    six  foo

# %%
#list if columnE== test or train
df2[df2["E"].isin(["test", "train"])]
# Out:
#      F          B    C    D      E    A
# 0  1.0 2021-03-01  1.0 -3.3   test  foo
# 1  1.0 2021-03-02  1.0 -3.3  train  foo
# 2  1.0 2021-03-03  1.0 -3.3   test  foo
# 3  1.0 2021-03-04  1.0 -3.3  train  foo

# %%
#adding columns to df manually
#dimensions should match

df["E"]=["one", "two", "", "3", "5", "9"]
df
# Out:
#                    A         B         C         D    E
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  one
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016  two
# 2021-03-03  1.499753  0.605885  0.141623  0.312358
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156    3
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565    5
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064    9

# %%
df3 = pd.DataFrame(np.random.randn(6,1), index=dates, columns=list("H"))
df3
# Out:
#                    H
# 2021-03-01  0.145637
# 2021-03-02 -0.828078
# 2021-03-03  1.403464
# 2021-03-04 -0.252286
# 2021-03-05 -0.536988
# 2021-03-06  0.381734

# %%
#adding new columns or replacing content of columns, depending if E==new column or E already exist

df["E"] = df3
df
# Out:
#                    A         B         C         D         E
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734

# %%
df.loc[:,"J"] = np.array([4.1] * len(df))
df
# Out:
#                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1

# %%
#copy with () and wo. () produces different results

df4 = df.copy()
df4
# Out:
#                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1

# %%
df4.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# J    float64
# dtype: object

# %%
df4 = df
df4
# Out:
#                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1

# %%
df4.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# J    float64
# dtype: object

# %%
#bound method NDFrame.copy of
#dtype and dtypes don't work over df4

df4=df.copy
df4
# Out:
# <bound method NDFrame.copy of                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1>

# %%
df
# Out:
#                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1

# %%
#adding an empty column and they adding some elements to that column
df1=df.reindex(index=dates[0:4],columns=list(df.columns)+["F"])
df1.loc[dates[0]:dates[1], "F"] = .25
df1
# Out:
#                    A         B         C         D         E    J     F
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1  0.25
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1  0.25
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1   NaN
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1   NaN

# %%
#drop nan but df is still the same
df1.dropna(how="any")
# Out:
#                    A         B         C         D         E    J     F
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1  0.25
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1  0.25

# %%
dft=df1.dropna(how="any")
dft
# Out:
#                    A         B         C         D         E    J     F
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1  0.25
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1  0.25

# %%
#average over columns/variables
df.mean()
# Out:
# A    0.659006
# B   -0.261585
# C   -0.693345
# D   -0.151777
# E    0.052247
# J    4.100000
# dtype: float64

# %%
#average over observations/rows
df.mean(1)
# Out:
# 2021-03-01   -0.018549
# 2021-03-02    0.650186
# 2021-03-03    1.343847
# 2021-03-04    0.717754
# 2021-03-05    0.221403
# 2021-03-06    0.789904
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1

# %%
#cummulative sum
df.apply(np.cumsum)
# Out:
#                    A         B         C         D         E     J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637   4.1
# 2021-03-02  1.092825 -0.695961 -1.338922 -2.785678 -0.682441   8.2
# 2021-03-03  2.592578 -0.090076 -1.197299 -2.473320  0.721023  12.3
# 2021-03-04  3.254281 -1.420883 -2.188538 -0.354164  0.468737  16.4
# 2021-03-05  3.102345 -1.971468 -3.782174 -0.292599 -0.068251  20.5
# 2021-03-06  3.954038 -1.569511 -4.160072 -0.910663  0.313483  24.6

# %%
df
# Out:
#                    A         B         C         D         E    J
# 2021-03-01 -0.136457 -1.680479 -0.785332 -1.754661  0.145637  4.1
# 2021-03-02  1.229282  0.984518 -0.553590 -1.031016 -0.828078  4.1
# 2021-03-03  1.499753  0.605885  0.141623  0.312358  1.403464  4.1
# 2021-03-04  0.661703 -1.330807 -0.991239  2.119156 -0.252286  4.1
# 2021-03-05 -0.151936 -0.550585 -1.593636  0.061565 -0.536988  4.1
# 2021-03-06  0.851693  0.401958 -0.377898 -0.618064  0.381734  4.1

# %%
#max of each column minus min
df.apply(lambda x:x.max() - x.min())
# Out:
# A    1.651689
# B    2.664996
# C    1.735258
# D    3.873818
# E    2.231542
# J    0.000000
# dtype: float64
